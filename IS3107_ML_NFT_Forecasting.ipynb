# %%
from google.cloud import bigquery
from google.colab import auth
from copy import deepcopy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Packages for ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.utils import plot_model

# %%
auth.authenticate_user()

# %%
client = bigquery.Client(project='nft-dashboard-381202')

# %%
Query = f"""
    SELECT *
    FROM `nft-dashboard-381202.nfts_pipeline.nfts_pipeline_collection_Cryptopunks`
    ORDER BY block_number ASC
"""
data = client.query(Query).to_dataframe()

# %%
data.head()
# Out:
#                            collection_address  marketplace token_id  \
# 0  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks      544
# 1  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     3134
# 2  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     5056
# 3  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     5719
# 4  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     6548
#
#                                        seller  \
# 0  0xc352b534e8b987e036a93539fd6897f53488e56a
# 1  0x5b098b00621eda6a96b7a476220661ad265f083f
# 2  0xc352b534e8b987e036a93539fd6897f53488e56a
# 3  0x5b098b00621eda6a96b7a476220661ad265f083f
# 4  0x5b098b00621eda6a96b7a476220661ad265f083f
#
#                                         buyer price_currency        price  \
# 0  0x5b098b00621eda6a96b7a476220661ad265f083f            ETH  0.010000000
# 1  0xc352b534e8b987e036a93539fd6897f53488e56a            ETH  0.010000000
# 2  0x00bd9fd57c423a1b1c969823d409156d90974d77            ETH  0.100000000
# 3  0x00bd3a6660309fb9e0129b9b777a9ccb9c2869dc            ETH  0.040000000
# 4  0x00bd3a6660309fb9e0129b9b777a9ccb9c2869dc            ETH  0.030000000
#
#   protocol_fee_currency protocol_fee  \
# 0                  None          0.0
# 1                  None          0.0
# 2                  None          0.0
# 3                  None          0.0
# 4                  None          0.0
#
#                                     transaction_hash  block_number
# 0  0xb28b5f2c186bf534e4fc4b8604b1496c9632e4226942...       3919706
# 1  0x65579455ac3227e7b3db72b4e359e988bb16cae6d26c...       3919721
# 2  0xd79cca9282c06a0edb8f9426aae734119f0f2ed0d968...       3919847
# 3  0x03c36b107006386b2db0e77667cc3fd4321d03668438...       3919887
# 4  0x85467bb2cbbdbea4542baa0307729e8a8c1a119dcf57...       3919893

# %% [markdown]
# ### Data Preprocessing and EDA

# %%
data['price'] = data['price'].astype(float)
# Normalize input data
scaler = MinMaxScaler()
data['price'] = scaler.fit_transform(data[['price']])

# data['price_diff'] = data['price'].diff()
# data['price_pct_change'] = data['price'].pct_change()
# data = data.dropna(subset=['price_diff'])
# data = data.dropna(subset=['price_pct_change'])
# Drop non-numerical columns
# data = data.drop(['collection_address', 'marketplace', 'token_id', 'seller', 'buyer', 'price_currency', 'protocol_fee_currency', 'protocol_fee', 'transaction_hash'], axis=1)

# %%
data
# Out:
#                               collection_address  marketplace token_id  \
# 0     0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks      544
# 1     0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     3134
# 2     0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     5056
# 3     0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     5719
# 4     0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     6548
# ...                                          ...          ...      ...
# 5988  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     3179
# 5989  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     3853
# 5990  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     3082
# 5991  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     6160
# 5992  0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB  cryptopunks     5558
#
#                                           seller  \
# 0     0xc352b534e8b987e036a93539fd6897f53488e56a
# 1     0x5b098b00621eda6a96b7a476220661ad265f083f
# 2     0xc352b534e8b987e036a93539fd6897f53488e56a
# 3     0x5b098b00621eda6a96b7a476220661ad265f083f
# 4     0x5b098b00621eda6a96b7a476220661ad265f083f
# ...                                          ...
# 5988  0x7ea6030486fabd4844785c99a13dfd66ca05b386
# 5989  0x7ea6030486fabd4844785c99a13dfd66ca05b386
# 5990  0x665498c14f80647d2a57a1f54eee4aaa9920fae8
# 5991  0x219688c6156edea2e2ca7e2036c1c5b7f6451169
# 5992  0x8ed1374ee2601eb3fd635978b17de61b2a7b3b82
#
#                                            buyer price_currency     price  \
# 0     0x5b098b00621eda6a96b7a476220661ad265f083f            ETH  0.000067
# 1     0xc352b534e8b987e036a93539fd6897f53488e56a            ETH  0.000067
# 2     0x00bd9fd57c423a1b1c969823d409156d90974d77            ETH  0.000667
# 3     0x00bd3a6660309fb9e0129b9b777a9ccb9c2869dc            ETH  0.000267
# 4     0x00bd3a6660309fb9e0129b9b777a9ccb9c2869dc            ETH  0.000200
# ...                                          ...            ...       ...
# 5988  0x641cf19cbd83666d8e21652981db09088568528b            ETH  0.029333
# 5989  0x865c964edc75e0f1f5c0631ea068baac2e490e57            ETH  0.033333
# 5990  0x641cf19cbd83666d8e21652981db09088568528b            ETH  0.030000
# 5991  0xbf6ccf49cc2874f01916d747a8fe97f14a082be0            ETH  0.026600
# 5992  0xbf6ccf49cc2874f01916d747a8fe97f14a082be0            ETH  0.026667
#
#      protocol_fee_currency protocol_fee  \
# 0                     None          0.0
# 1                     None          0.0
# 2                     None          0.0
# 3                     None          0.0
# 4                     None          0.0
# ...                    ...          ...
# 5988                  None          0.0
# 5989                  None          0.0
# 5990                  None          0.0
# 5991                  None          0.0
# 5992                  None          0.0
#
#                                        transaction_hash  block_number
# 0     0xb28b5f2c186bf534e4fc4b8604b1496c9632e4226942...       3919706
# 1     0x65579455ac3227e7b3db72b4e359e988bb16cae6d26c...       3919721
# 2     0xd79cca9282c06a0edb8f9426aae734119f0f2ed0d968...       3919847
# 3     0x03c36b107006386b2db0e77667cc3fd4321d03668438...       3919887
# 4     0x85467bb2cbbdbea4542baa0307729e8a8c1a119dcf57...       3919893
# ...                                                 ...           ...
# 5988  0xd61c95603f73e7790ab5dd3ddb66788f6cc035220e84...      11505648
# 5989  0x2ce4d150ddfb7202575907cb2eb9617e297e8624abbc...      11505769
# 5990  0x943300cfd15c7b40cf459cdc125c8fa629b03a67c8f6...      11505894
# 5991  0x16c2836c54d9f6b2cffc5b7d9a31d34b29ebb75f9967...      11505938
# 5992  0x31d18c584732290a35ad39abb97aa1574cdde2f6ca8c...      11505938
#
# [5993 rows x 11 columns]

# %%
data.describe()
# Out:
#              price    block_number
# count  5993.000000          5993.0
# mean      0.011466  7971058.859169
# std       0.029506  2615240.663443
# min       0.000000       3919706.0
# 25%       0.001667       5179512.0
# 50%       0.003667       8552860.0
# 75%       0.010600      10322870.0
# max       1.000000      11505938.0

# %%
cols_plot = ['price', 'block_number']
graphs = data[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for graph in graphs:
    graph.set_xlabel('Block Number'),
    graph.set_ylabel('Price')

# %%
X = []
Y = []
window_size = 10
for i in range(1, len(data) - window_size - 1, 1):
    first = data.iloc[i, 6]  # The 'price' column index is 6
    features = []
    label = []
    eps = 1e-8 # A small constant value to avoid division by zero
    for j in range(window_size):
        rel_price = data.iloc[i + j, 6]
        features.append(rel_price)
    label.append(data.iloc[i + window_size, 6])
    X.append(np.array(features).reshape(window_size, 1))
    Y.append(np.array(label).reshape(1, 1))
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

train_X = train_X.reshape(train_X.shape[0],1,window_size,1)
test_X = test_X.reshape(test_X.shape[0],1,window_size,1)

print(train_X.shape)
print(test_X.shape)
# Out:
# (4784, 1, 10, 1)
# (1197, 1, 10, 1)

# %%
def construct_model():
  model = tf.keras.Sequential()

  # CNN layers
  model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, window_size, 1))))
  model.add(TimeDistributed(MaxPooling1D(2)))
  model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='tanh')))
  model.add(TimeDistributed(MaxPooling1D(2)))
  # model.add(TimeDistributed(Conv1D(32, kernel_size=3, activation='relu')))
  # model.add(TimeDistributed(MaxPooling1D(2)))
  model.add(TimeDistributed(Flatten()))
  # model.add(Dense(5, kernel_regularizer=L2(0.01)))

  # LSTM layers
  model.add(Bidirectional(LSTM(50, return_sequences=True)))
  model.add(Dropout(0.5))
  # model.add(Bidirectional(LSTM(window_size, return_sequences=False)))
  # model.add(Dropout(0.5))

  #Final layers
  model.add(Dense(1, activation='linear'))
  model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
  return model

# Train the model
model = construct_model()
results = model.fit(train_X, train_Y, validation_data=(test_X,test_Y), epochs=50, batch_size=50, verbose=1, shuffle =True)
# Out:
# Epoch 1/50
# 96/96 [==============================] - 8s 19ms/step - loss: 8.7031e-04 - mse: 8.7031e-04 - mae: 0.0097 - val_loss: 4.2666e-04 - val_mse: 4.2666e-04 - val_mae: 0.0061
# Epoch 2/50
# 96/96 [==============================] - 1s 8ms/step - loss: 8.2336e-04 - mse: 8.2336e-04 - mae: 0.0085 - val_loss: 5.0486e-04 - val_mse: 5.0486e-04 - val_mae: 0.0139
# Epoch 3/50
# 96/96 [==============================] - 1s 10ms/step - loss: 8.5145e-04 - mse: 8.5145e-04 - mae: 0.0096 - val_loss: 4.4689e-04 - val_mse: 4.4689e-04 - val_mae: 0.0072
# Epoch 4/50
# 96/96 [==============================] - 1s 10ms/step - loss: 8.1817e-04 - mse: 8.1817e-04 - mae: 0.0088 - val_loss: 4.4565e-04 - val_mse: 4.4565e-04 - val_mae: 0.0103
# Epoch 5/50
# 96/96 [==============================] - 1s 9ms/step - loss: 8.0698e-04 - mse: 8.0698e-04 - mae: 0.0086 - val_loss: 4.2496e-04 - val_mse: 4.2496e-04 - val_mae: 0.0084
# Epoch 6/50
# 96/96 [==============================] - 1s 9ms/step - loss: 8.1903e-04 - mse: 8.1903e-04 - mae: 0.0087 - val_loss: 4.7021e-04 - val_mse: 4.7021e-04 - val_mae: 0.0124
# Epoch 7/50
# 96/96 [==============================] - 1s 8ms/step - loss: 8.0972e-04 - mse: 8.0972e-04 - mae: 0.0091 - val_loss: 4.2894e-04 - val_mse: 4.2894e-04 - val_mae: 0.0090
# Epoch 8/50
# 96/96 [==============================] - 1s 8ms/step - loss: 8.0146e-04 - mse: 8.0146e-04 - mae: 0.0081 - val_loss: 4.5429e-04 - val_mse: 4.5429e-04 - val_mae: 0.0113
# Epoch 9/50
# 96/96 [==============================] - 1s 8ms/step - loss: 8.0144e-04 - mse: 8.0144e-04 - mae: 0.0086 - val_loss: 4.2556e-04 - val_mse: 4.2556e-04 - val_mae: 0.0056
# Epoch 10/50
# 96/96 [==============================] - 1s 10ms/step - loss: 8.0502e-04 - mse: 8.0502e-04 - mae: 0.0082 - val_loss: 4.2339e-04 - val_mse: 4.2339e-04 - val_mae: 0.0063
# Epoch 11/50
# 96/96 [==============================] - 1s 15ms/step - loss: 8.0724e-04 - mse: 8.0724e-04 - mae: 0.0082 - val_loss: 4.2494e-04 - val_mse: 4.2494e-04 - val_mae: 0.0062
# Epoch 12/50
# 96/96 [==============================] - 1s 14ms/step - loss: 8.0026e-04 - mse: 8.0026e-04 - mae: 0.0087 - val_loss: 4.2010e-04 - val_mse: 4.2010e-04 - val_mae: 0.0077
# Epoch 13/50
# 96/96 [==============================] - 1s 8ms/step - loss: 8.0205e-04 - mse: 8.0205e-04 - mae: 0.0085 - val_loss: 4.3373e-04 - val_mse: 4.3373e-04 - val_mae: 0.0098
# Epoch 14/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9620e-04 - mse: 7.9620e-04 - mae: 0.0083 - val_loss: 4.5073e-04 - val_mse: 4.5073e-04 - val_mae: 0.0098
# Epoch 15/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9532e-04 - mse: 7.9532e-04 - mae: 0.0082 - val_loss: 4.2883e-04 - val_mse: 4.2883e-04 - val_mae: 0.0083
# Epoch 16/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8949e-04 - mse: 7.8949e-04 - mae: 0.0082 - val_loss: 4.2757e-04 - val_mse: 4.2757e-04 - val_mae: 0.0080
# Epoch 17/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9707e-04 - mse: 7.9707e-04 - mae: 0.0079 - val_loss: 4.2430e-04 - val_mse: 4.2430e-04 - val_mae: 0.0069
# Epoch 18/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9250e-04 - mse: 7.9250e-04 - mae: 0.0081 - val_loss: 4.2337e-04 - val_mse: 4.2337e-04 - val_mae: 0.0064
# Epoch 19/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8881e-04 - mse: 7.8881e-04 - mae: 0.0079 - val_loss: 4.4116e-04 - val_mse: 4.4116e-04 - val_mae: 0.0080
# Epoch 20/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9319e-04 - mse: 7.9319e-04 - mae: 0.0087 - val_loss: 4.2768e-04 - val_mse: 4.2768e-04 - val_mae: 0.0061
# Epoch 21/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8945e-04 - mse: 7.8945e-04 - mae: 0.0081 - val_loss: 4.3950e-04 - val_mse: 4.3950e-04 - val_mae: 0.0057
# Epoch 22/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8702e-04 - mse: 7.8702e-04 - mae: 0.0079 - val_loss: 4.2376e-04 - val_mse: 4.2376e-04 - val_mae: 0.0076
# Epoch 23/50
# 96/96 [==============================] - 1s 9ms/step - loss: 7.9031e-04 - mse: 7.9031e-04 - mae: 0.0082 - val_loss: 4.2446e-04 - val_mse: 4.2446e-04 - val_mae: 0.0085
# Epoch 24/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9288e-04 - mse: 7.9288e-04 - mae: 0.0084 - val_loss: 4.2774e-04 - val_mse: 4.2774e-04 - val_mae: 0.0081
# Epoch 25/50
# 96/96 [==============================] - 1s 13ms/step - loss: 7.8243e-04 - mse: 7.8243e-04 - mae: 0.0081 - val_loss: 4.2480e-04 - val_mse: 4.2480e-04 - val_mae: 0.0073
# Epoch 26/50
# 96/96 [==============================] - 1s 14ms/step - loss: 7.8205e-04 - mse: 7.8205e-04 - mae: 0.0080 - val_loss: 4.2888e-04 - val_mse: 4.2888e-04 - val_mae: 0.0061
# Epoch 27/50
# 96/96 [==============================] - 1s 11ms/step - loss: 7.8606e-04 - mse: 7.8606e-04 - mae: 0.0080 - val_loss: 4.3692e-04 - val_mse: 4.3692e-04 - val_mae: 0.0062
# Epoch 28/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.9276e-04 - mse: 7.9276e-04 - mae: 0.0083 - val_loss: 4.2190e-04 - val_mse: 4.2190e-04 - val_mae: 0.0063
# Epoch 29/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8185e-04 - mse: 7.8185e-04 - mae: 0.0078 - val_loss: 4.3311e-04 - val_mse: 4.3311e-04 - val_mae: 0.0083
# Epoch 30/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8073e-04 - mse: 7.8073e-04 - mae: 0.0080 - val_loss: 4.2299e-04 - val_mse: 4.2299e-04 - val_mae: 0.0063
# Epoch 31/50
# 96/96 [==============================] - 1s 9ms/step - loss: 7.7382e-04 - mse: 7.7382e-04 - mae: 0.0078 - val_loss: 4.4049e-04 - val_mse: 4.4049e-04 - val_mae: 0.0077
# Epoch 32/50
# 96/96 [==============================] - 1s 9ms/step - loss: 7.8191e-04 - mse: 7.8191e-04 - mae: 0.0083 - val_loss: 4.3621e-04 - val_mse: 4.3621e-04 - val_mae: 0.0092
# Epoch 33/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.8089e-04 - mse: 7.8089e-04 - mae: 0.0080 - val_loss: 4.2930e-04 - val_mse: 4.2930e-04 - val_mae: 0.0079
# Epoch 34/50
# 96/96 [==============================] - 1s 9ms/step - loss: 7.7720e-04 - mse: 7.7720e-04 - mae: 0.0080 - val_loss: 4.2654e-04 - val_mse: 4.2654e-04 - val_mae: 0.0058
# Epoch 35/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.7699e-04 - mse: 7.7699e-04 - mae: 0.0081 - val_loss: 4.2861e-04 - val_mse: 4.2861e-04 - val_mae: 0.0064
# Epoch 36/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6548e-04 - mse: 7.6548e-04 - mae: 0.0077 - val_loss: 4.3747e-04 - val_mse: 4.3747e-04 - val_mae: 0.0085
# Epoch 37/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.7852e-04 - mse: 7.7852e-04 - mae: 0.0082 - val_loss: 4.2270e-04 - val_mse: 4.2270e-04 - val_mae: 0.0063
# Epoch 38/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.7801e-04 - mse: 7.7801e-04 - mae: 0.0081 - val_loss: 4.3544e-04 - val_mse: 4.3544e-04 - val_mae: 0.0061
# Epoch 39/50
# 96/96 [==============================] - 1s 11ms/step - loss: 7.8213e-04 - mse: 7.8213e-04 - mae: 0.0087 - val_loss: 4.6056e-04 - val_mse: 4.6056e-04 - val_mae: 0.0076
# Epoch 40/50
# 96/96 [==============================] - 1s 14ms/step - loss: 7.6470e-04 - mse: 7.6470e-04 - mae: 0.0076 - val_loss: 4.5237e-04 - val_mse: 4.5237e-04 - val_mae: 0.0083
# Epoch 41/50
# 96/96 [==============================] - 1s 13ms/step - loss: 7.8243e-04 - mse: 7.8243e-04 - mae: 0.0085 - val_loss: 4.2475e-04 - val_mse: 4.2475e-04 - val_mae: 0.0067
# Epoch 42/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6283e-04 - mse: 7.6283e-04 - mae: 0.0078 - val_loss: 4.2761e-04 - val_mse: 4.2761e-04 - val_mae: 0.0073
# Epoch 43/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6646e-04 - mse: 7.6646e-04 - mae: 0.0075 - val_loss: 4.3840e-04 - val_mse: 4.3840e-04 - val_mae: 0.0060
# Epoch 44/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.7301e-04 - mse: 7.7301e-04 - mae: 0.0080 - val_loss: 4.4552e-04 - val_mse: 4.4552e-04 - val_mae: 0.0068
# Epoch 45/50
# 96/96 [==============================] - 1s 9ms/step - loss: 7.8521e-04 - mse: 7.8521e-04 - mae: 0.0084 - val_loss: 4.3589e-04 - val_mse: 4.3589e-04 - val_mae: 0.0087
# Epoch 46/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6310e-04 - mse: 7.6310e-04 - mae: 0.0078 - val_loss: 4.4146e-04 - val_mse: 4.4146e-04 - val_mae: 0.0063
# Epoch 47/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6728e-04 - mse: 7.6728e-04 - mae: 0.0080 - val_loss: 4.3226e-04 - val_mse: 4.3226e-04 - val_mae: 0.0061
# Epoch 48/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6957e-04 - mse: 7.6957e-04 - mae: 0.0080 - val_loss: 4.4770e-04 - val_mse: 4.4770e-04 - val_mae: 0.0100
# Epoch 49/50
# 96/96 [==============================] - 1s 8ms/step - loss: 7.6122e-04 - mse: 7.6122e-04 - mae: 0.0079 - val_loss: 4.4037e-04 - val_mse: 4.4037e-04 - val_mae: 0.0063
# Epoch 50/50
# 96/96 [==============================] - 1s 9ms/step - loss: 7.6912e-04 - mse: 7.6912e-04 - mae: 0.0079 - val_loss: 4.4562e-04 - val_mse: 4.4562e-04 - val_mae: 0.0072

# %%
plt.plot(results.history['loss'], label='train loss')
plt.plot(results.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
# Print_the_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 8, 64)         256
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 4, 64)         0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 2, 128)        24704
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 1, 128)        0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 128)           0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 1, 100)           71600
#  l)
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  dense (Dense)               (None, 1, 1)              101
#
# =================================================================
# Total params: 96,661
# Trainable params: 96,661
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.evaluate(test_X, test_Y)
# Out:
# 38/38 [==============================] - 0s 3ms/step - loss: 4.4562e-04 - mse: 4.4562e-04 - mae: 0.0072
# [0.0004456228925846517, 0.0004456228925846517, 0.007169855758547783]

# %%
from sklearn.metrics import explained_variance_score, mean_poisson_deviance, mean_gamma_deviance
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
test_label = test_Y.reshape(-1,1)
var = explained_variance_score(test_label, yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_label, yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_label, yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.221443
# R2 Score: 0.221443
# Max Error: 0.315774

# %%
predicted  = model.predict(test_X)
predicted = np.array(predicted[:,0]).reshape(-1,1)
real_prices = deepcopy(test_label)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    # Use 'price' of NFT to predict
    temp = data.iloc[j, 6]
    real_prices[j - len_t] = real_prices[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
# Out:
# 38/38 [==============================] - 0s 4ms/step

# %%
# Set the figure size
plt.figure(figsize=(15, 8))

# Remove outliers by clipping the values
threshold = 0.45
predicted_clipped = np.clip(predicted, 0, threshold)
real_prices_clipped = np.clip(real_prices, 0, threshold)

# Plot the clipped data
plt.plot(predicted_clipped, color='green', label='Predicted NFT Price', alpha=0.8)
plt.plot(real_prices_clipped, color='red', label='Real NFT Price', alpha=0.5)

# Set the title, labels, and legend
plt.title('NFT Price Prediction')
plt.xlabel('Block')
plt.ylabel('NFT Price')
plt.legend()

# Show the plot
plt.show()
